# %%
# 버블 정렬 코드
arr = [2, 4, 1, 3]  # 정렬하고자 하는 리스트의 길이가 4니까?

for i in range(len(arr)-1, 0, -1):  # 총 3회 시행, 
    for j in range(i): # 각 시행 횟수 안에서, 3 2 1 번씩 비교 할것 
        if arr[j] > arr[j+1]: # 내가 오른쪽 녀석보다 크다면?
            arr[j], arr[j+1] = arr[j+1], arr[j]  # 자리를 바꾼다!

print(arr)
# Out:
# [1, 2, 3, 4]

# %%
nums = [1,3,2,2,1,2,3,1,1,2,3,2]

cnt = {}

for num in nums:
    cnt[num] = cnt.get(num, 0) + 1  

sorted_cnt = sorted(cnt, key=lambda x: -x[1])
print(sorted_cnt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       5 for num in nums:
#       6     cnt[num] = cnt.get(num, 0) + 1
# ----> 8 sorted_cnt = sorted(cnt, key=lambda x: -x[1])
#       9 print(sorted_cnt)
#
# Cell In[7], line 8, in <lambda>(x)
#       5 for num in nums:
#       6     cnt[num] = cnt.get(num, 0) + 1
# ----> 8 sorted_cnt = sorted(cnt, key=lambda x: -x[1])
#       9 print(sorted_cnt)
#
# TypeError: 'int' object is not subscriptable
